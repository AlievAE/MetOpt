# %%
import scipy.sparse as sp
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.sparse.linalg

# %% [markdown]
# ##  Первое задание. Предобусловленный метод сопряженных градиентов.

# %% [markdown]
# Задача, решить линейную систему:
# $$
# Ax = b
# $$
#
# Где $A$ -  матрица оператора Лапласа, $b$ константный вектор.
#
#
#
# $$
# \begin{equation}
# A =  \frac{1}{h^2}
# \begin{pmatrix}
# 2 & -1 & \cdots & 0 &0 \\
# -1 & 2 & \cdots & 0 & 0\\
# \vdots  & \vdots  & \ddots & \vdots & \vdots \\
# 0 & 0& \cdots &-2 & 1 \\
# 0 & 0& \cdots &-1 & 1
# \end{pmatrix}
# \label{eq::Amat}
# \end{equation}
# $$
#
# $h$ - Шаг сетки. Пусть сетка равномерная, тогда $h=\frac{1}{n+1}$, где $n+1$ - количество узлов в сетке.
#
#
# Задать такую матрицу и вектор можно следкющим образом

# %%
#n можно взять любым больше 100. Перевести разрженную матрицу в плотную можно мотодом toarray()
np.random.seed(23)

n = 1000
A =  sp.diags([-1, 2, -1], [-1,0,1], shape = (n, n)) 
A =  A *(n+1)**2

#константный вектор правой части
b =  np.ones(n) * 6.

# рандомная начальная точка
x0 = np.random.rand(n)

# %% [markdown]
# Число обусловленности такой матрицы будет большим

# %%
w, _= np.linalg.eig(A.toarray())
np.linalg.cond(A.toarray()), max(w)/min(w)
# Out:
# (406095.04265169933, 406095.0426782732)

# %%
np.isclose(max(w)/min(w), np.linalg.cond(A.toarray()))
# Out:
# True

# %% [markdown]
# Проверить, как отработает метод сопряженных градиентов на такой задаче. (Метод можно взять из семинара)

# %%
def ConjugateGradient(x0, A, b, tol=1e-8, callback=None):
    x = x0
    r = b - A.dot(x0) 
    p = r
    while np.linalg.norm(r) > tol:
        alpha = r.dot(r) / p.dot(A.dot(p))
        x = x + alpha * p
        r_next = r - alpha * A.dot(p)
        beta = r_next.dot(r_next) / r.dot(r)
        p = r_next + beta * p
        r = r_next
        if callback is not None:
            callback((x, r))
    return x

# %%
r_arr = []
res = ConjugateGradient(x0, A, b, callback=lambda el: r_arr.append(np.linalg.norm(el[1])))

# %%
plt.figure(figsize=(15, 9))
plt.plot(r_arr, lw=3)
plt.yscale('log')
plt.grid(':')
plt.xlabel('Номер итерации', fontsize=18)
plt.ylabel('$|r_k|$', fontsize=18)
plt.title('Зависимость нормы $r_k$ для метода сопряженных градиентов', fontsize=18)
plt.show()

# %% [markdown]
# Написать метод сопряженных градиентов, учитывая действие предобуславлевателя.
#
#
# ![](PCG.png)
#
# ([Полный текст тут](http://www.cse.psu.edu/~b58/cse456/lecture20.pdf))

# %% [markdown]
# Написать метод сопряженных градиентов, учитывая действие предобуславлевателя.

# %%
def PreconditionedCG(x0, A, b, M, tol=1e-8, callback=None):
    x = x0
    r = b - A.dot(x)
    z = np.linalg.inv(M) @ r
    p = z
    w = A @ p
    alpha = (r.T @ z) / (p.T @ w)
    x = x + alpha * p
    prev_r = r
    r = r - alpha * w

    while np.linalg.norm(r) > tol:
        prev_z = z
        z = np.linalg.inv(M) @ r
        beta = (r.T @ z) / (prev_r.T @ prev_z)
        
        p = z + beta * p
        w = A.dot(p)
        alpha = (r.T @ z) / (p.T @ w)
        x = x + alpha * p
        prev_r = r
        r = r - alpha * w
        
        if callback is not None:
            callback((x, r))
    return x

# %% [markdown]
# Проверить работу метода на предобуславлевателе Гаусса-Зейделя. Обратите внимание, что есть симметричный и не симметричные варианты. Какой надо взять?([Статья с предобуславлевателями для метода сопряжённых градиентов](https://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.592.1575&rep=rep1&type=pdf))

# %% [markdown]
# Конечно же, надо брать симметричный вариант, как иначе.

# %%
D = np.diag(np.diag(A.toarray()))
L = np.tril(A.toarray(), -1)
U = np.triu(A.toarray(), 1)

M = (D + L) @ np.linalg.inv(D) @ (D + U)

r_prec = []

res = PreconditionedCG(x0, A, b, M, callback=lambda el: r_prec.append(np.linalg.norm(el[1])))
print(np.allclose(np.zeros(n), A @ res - b))
# Out:
# True

# %%
plt.figure(figsize=(15, 9))
plt.plot(r_arr, lw=3, label='Сопряженные градиенты')
plt.plot(r_prec, lw=3, label='Сопряженные градиенты, предобусловленные Гауссом-Зейделем')
plt.yscale('log')
plt.grid(':')
plt.xlabel('Номер итерации', fontsize=18)
plt.ylabel('$|r_k|$', fontsize=18)
plt.title('Сравнение сходимости методов', fontsize=18)
plt.legend()
plt.show()

# %% [markdown]
# Сравните результат работы предобусловленной и непредобусловленной версии

# %% [markdown]
# Наглядно видим на графике, что предобуславливатель серьезно улучшил скорость сходимости. Без него сошлось за ~1000 итераций, с ним же - ~400

# %% [markdown]
# ## Второе задание. Метод момента

# %% [markdown]
# Реализовать Метод момента.

# %% [markdown]
# ![](Momentum.png)
#
# ([Картинка отсюда](https://cs231n.github.io/neural-networks-3/))

# %% [markdown]
# Сравнить его с методом Нестерова и методом градиентного спуска, которые были преддставлены на семинаре. Сравнивать можно на $2D$  задаче с семинара

# %%
sns.set()
np.random.seed(322)
n=100
# строим и нормализуем матрицу
A = np.array([[4,3], [3,4]])
U = np.random.rand(2, 2)
Q, _ = np.linalg.qr(U)
A = Q.dot(A).dot(Q.T)
A = (A + A.T) * 0.5

n_points = 50

u = np.linspace(-4, 4, n_points)
x, y = np.meshgrid(u, u)
b = np.random.rand(2)
X = np.vstack([x.flatten(), y.flatten()])
print(X.shape, A.shape)
# строим изолинии
f_x = X.T @ A @ X - b @ X

f_x = np.diag(f_x).reshape(n_points, n_points)


# начальное приближение
x0 = np.array([-4. , -4.])


# вспомогательные функции для кастомного Gradient DEscent
f = lambda x: 0.5 * x.dot(A.dot(x)) - b.dot(x)
grad_f = lambda x: A.dot(x) - b
# Out:
# (2, 2500) (2, 2)

# %%
def get_x_y_from_callback(array, x0):
    x_array = [x0[0]]
    y_array = [x0[0]]
    for el in array:
        x_array.append(el[0])
        y_array.append(el[1])
        
    return np.array(x_array), np.array(y_array)

def backtracking (x, f, grad_f, rho, alpha0, beta1, beta2):
    # 0 < rho < 1
    # alpha0 - initial guess of step size
    # beta1 and beta2 - constants from conditions
    alpha = alpha0
    phi1 = f(x) -  beta1 * alpha * grad_f(x).dot(grad_f(x))
    phi2 = f(x) -  beta2 * alpha * grad_f(x).dot(grad_f(x))    
    f_k = f(x - alpha * grad_f(x)) 
    while not ((f_k <=phi1) and 
              (f_k >=phi2)):
        alpha *= rho
            
        phi1 = f(x) -  beta1 * alpha * grad_f(x).dot(grad_f(x))
        phi2 = f(x) -  beta2 * alpha * grad_f(x).dot(grad_f(x))    
        f_k = f(x - alpha * grad_f(x)) 
        if alpha < 1e-17:
            return alpha / rho
    return alpha

def GradientDescent(f, gradf, x0, max_iter=1000, tol=1e-8,  rho=0.7, beta1=0.3):
    x = x0.copy()
    iteration = 0
    conv_array = []

    while True:

        beta2 = 1. -beta1
        alpha = backtracking (x, f, gradf, rho=rho, alpha0=1., beta1=beta1, beta2=beta2)
        gradient = gradf(x)
        x = x - alpha * gradient
        iteration += 1
        if np.linalg.norm(gradf(x)) < tol:
            break
        if iteration >= max_iter:
            break
        conv_array.append(x)
    res = {"x": x, "num_iter": iteration, "tol": np.linalg.norm(gradf(x)),  "conv_array": conv_array}
    return res

def NesterovAcceleratedGD(f, gradf, x0, momentum =0.9, max_iter=1000, tol=1e-8,  rho=0.5, beta1=0.2):
    x = x0.copy()
    iteration = 0
    conv_array = []

    change = np.zeros(x.shape)
   
    while True:

        beta2 = 1. -beta1
        proj = x + momentum * change
        
        gradient = gradf(proj)
        alpha = backtracking (x, f, gradf, rho=rho, alpha0=1., beta1=beta1, beta2=beta2)
        change = momentum * change - alpha * gradient
        x = x  + change
        iteration += 1
        if np.linalg.norm(gradf(x)) < tol:
            break
        if iteration >= max_iter:
            break
        conv_array.append(x)
    res = {"x": x, "num_iter": iteration, "tol": np.linalg.norm(gradf(x)),  "conv_array": conv_array}
    return res

def Momentum(f, gradf, x0, mu=0.9, tol=1e-8, max_iter=1000, rho=0.8, beta1=0.33):
    x = x0.copy()
    iteration = 0
    conv_array = []

    v = 0
    
    while True:

        beta2 = 1. -beta1
        grad_ahead = gradf(x)
        alpha = backtracking(x, f, gradf, rho=rho, alpha0=1., beta1=beta1, beta2=beta2)
        
        # Momentum update
        v = mu * v + alpha * grad_ahead # integrate velocity
        x -= v # integrate position
        iteration += 1
        if np.linalg.norm(gradf(x)) < tol:
            break
        if iteration >= max_iter:
            break
        conv_array.append(x)
    res = {"x": x, "num_iter": iteration, "tol": np.linalg.norm(gradf(x)),  "conv_array": conv_array}
    return res

# %%
res_nest = NesterovAcceleratedGD(f, grad_f, x0, momentum =0.15)
x_nest, y_nest = get_x_y_from_callback(res_nest["conv_array"], x0)

res_gd = GradientDescent(f, grad_f, x0, rho=0.5, beta1=0.2)
x_gd, y_gd = get_x_y_from_callback(res['conv_array'], x0)

res_momentum = Momentum(f, grad_f, x0, rho=0.8, beta1=0.33, mu=0.5)
x_momentum, y_momentum = get_x_y_from_callback(res_momentum['conv_array'], x0)

# %%
plt.figure(figsize=(15, 9))
n_gd = res_gd['num_iter']
plt.plot(x_gd, y_gd, ls=':', lw=3, label=f'Gradient Descent, total {n_gd} iterations')
n_nest = res_nest['num_iter']
plt.plot(x_nest, y_nest, ls=':', lw=3, label=f'Nesterov Accelerated GD, total {n_nest} iterations')
n_momentum = res_momentum['num_iter']
plt.plot(x_momentum, y_momentum, ls=':', lw=3, label=f'Momentum, total {n_momentum} iterations')
plt.legend(loc="best", fontsize=20)
plt.contour(x, y, f_x)
plt.title('Сходимость изученных методов', fontsize=18)
plt.ylabel('y', fontsize=18)
plt.xlabel('x', fontsize=18)
plt.show()

# %% [markdown]
# Посмотрели, что все сходится куда надо. Другие выводы сделать сложно, ведь для качественной оценки скорости сходимости надо подбирать гиперпараметры, а не тыкать почти наугад.
